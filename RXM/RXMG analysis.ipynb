# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
xls = pd.ExcelFile('RXMG.xlsx')
df1 = pd.read_excel(xls, '4915')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 109 entries, 0 to 108
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Affiliate ID1          109 non-null    int64
#  1   eCPM                   109 non-null    float64
#  2   CTR                    109 non-null    float64
#  3   EPC                    109 non-null    float64
#  4   CLR                    109 non-null    float64
#  5   Name                   109 non-null    object
#  6   # Drops                109 non-null    int64
#  7   Click Rate             109 non-null    float64
#  8   Clicks                 109 non-null    int64
#  9   Data Provider (group)  109 non-null    object
#  10  Data Vertical          109 non-null    object
#  11  Date1                  109 non-null    datetime64[ns]
#  12  Delivered              109 non-null    int64
#  13  Offer ID1              109 non-null    int64
#  14  Offer Name1            109 non-null    object
#  15  Open Rate              109 non-null    float64
#  16  Opens                  109 non-null    int64
#  17  Operational Status1    109 non-null    object
#  18  Payout Type1           109 non-null    object
#  19  Remaining Budget       109 non-null    int64
#  20  Revenue                109 non-null    int64
#  21  Segment1               109 non-null    object
# dtypes: datetime64[ns](1), float64(6), int64(8), object(7)
# memory usage: 18.9+ KB

# %%
df1.describe()
# Out:
#        Affiliate ID1        eCPM         CTR         EPC         CLR  # Drops  \
# count     109.000000  109.000000  109.000000  109.000000  109.000000    109.0
# mean   460599.770642    4.150550    0.014434    0.278440    0.006870      1.0
# std       163.492362    3.496684    0.009293    0.142102    0.014959      0.0
# min    460121.000000    0.000000    0.001000    0.000000    0.000000      1.0
# 25%    460454.000000    1.620000    0.008200    0.200000    0.000000      1.0
# 50%    460628.000000    3.740000    0.012800    0.260000    0.003100      1.0
# 75%    460744.000000    5.540000    0.018500    0.360000    0.006400      1.0
# max    460828.000000   21.900000    0.053400    0.660000    0.085600      1.0
#
#        Click Rate       Clicks      Delivered  Offer ID1   Open Rate  \
# count  109.000000   109.000000     109.000000      109.0  109.000000
# mean     0.106915   597.504587   52829.587156     4915.0    0.140381
# std      0.046074   505.682315   69998.117589        0.0    0.067710
# min      0.027000    42.000000    6812.000000     4915.0    0.005000
# 25%      0.080100   283.000000   26151.000000     4915.0    0.101900
# 50%      0.101200   476.000000   38125.000000     4915.0    0.135000
# 75%      0.127800   759.000000   60720.000000     4915.0    0.171000
# max      0.281000  3621.000000  688381.000000     4915.0    0.342000
#
#                Opens  Remaining Budget     Revenue
# count     109.000000             109.0  109.000000
# mean     7157.889908               0.0  169.688073
# std     12827.574266               0.0  171.254343
# min       631.000000               0.0    0.000000
# 25%      2645.000000               0.0   68.000000
# 50%      4719.000000               0.0  119.000000
# 75%      7604.000000               0.0  204.000000
# max    130167.000000               0.0  935.000000

# %%
df1.duplicated().sum()
# Out:
# 0

# %%
df1.nunique()
# Out:
# Affiliate ID1             34
# eCPM                      96
# CTR                       93
# EPC                       47
# CLR                       54
# Name                       1
# # Drops                    1
# Click Rate                92
# Clicks                   105
# Data Provider (group)      2
# Data Vertical              9
# Date1                     52
# Delivered                109
# Offer ID1                  1
# Offer Name1                1
# Open Rate                 94
# Opens                    108
# Operational Status1        1
# Payout Type1               1
# Remaining Budget           1
# Revenue                   29
# Segment1                   7
# dtype: int64

# %%
plt.figure(figsize=(12, 7))
sns.heatmap(df1.corr(), annot = True)

# %%
#convert categorical variable to numerical variables
df = pd.get_dummies(df1)

# %%
plt.figure(figsize=(12, 7))
sns.heatmap(df.corr(), annot = True)

# %%
df.corr()
# Out:
#                                                     Affiliate ID1      eCPM  \
# Affiliate ID1                                            1.000000  0.215945
# eCPM                                                     0.215945  1.000000
# CTR                                                      0.190130  0.826402
# EPC                                                      0.112945  0.546380
# CLR                                                     -0.186480 -0.266749
# # Drops                                                       NaN       NaN
# Click Rate                                               0.120856  0.217015
# Clicks                                                  -0.118482  0.300535
# Delivered                                               -0.178661 -0.204482
# Offer ID1                                                     NaN       NaN
# Open Rate                                               -0.014846  0.694757
# Opens                                                   -0.116795 -0.020161
# Remaining Budget                                              NaN       NaN
# Revenue                                                 -0.035752  0.557383
# Name_First Access Solid B                                     NaN       NaN
# Data Provider (group)_Irvine                            -0.336122 -0.257573
# Data Provider (group)_Venice                             0.336122  0.257573
# Data Vertical_Auto Loan                                 -0.096243 -0.071618
# Data Vertical_Credit                                    -0.152069  0.271575
# Data Vertical_FHA                                       -0.308929 -0.154873
# Data Vertical_Grants                                    -0.025951 -0.138584
# Data Vertical_Internal                                  -0.200442 -0.166092
# Data Vertical_Paleo                                     -0.086191 -0.107558
# Data Vertical_Personal Loan                              0.552609  0.089131
# Data Vertical_Refinance                                 -0.071215 -0.113344
# Data Vertical_Rent To Own                               -0.171425 -0.166685
# Offer Name1_First Access Solid Black Visa Credi...            NaN       NaN
# Operational Status1_Live                                      NaN       NaN
# Payout Type1_1st PAGE SUBMIT                                  NaN       NaN
# Segment1_A14                                            -0.225733 -0.063048
# Segment1_A21                                             0.149096 -0.022905
# Segment1_MI                                             -0.242883 -0.176863
# Segment1_O1                                              0.032956  0.222694
# Segment1_O14                                             0.035416  0.041800
# Segment1_O21                                             0.344865  0.169260
# Segment1_O30                                            -0.171214 -0.104952
#
#                                                          CTR       EPC  \
# Affiliate ID1                                       0.190130  0.112945
# eCPM                                                0.826402  0.546380
# CTR                                                 1.000000  0.097217
# EPC                                                 0.097217  1.000000
# CLR                                                -0.342789 -0.033224
# # Drops                                                  NaN       NaN
# Click Rate                                          0.316271 -0.023298
# Clicks                                              0.314267  0.044971
# Delivered                                          -0.255454 -0.082345
# Offer ID1                                                NaN       NaN
# Open Rate                                           0.799631  0.107899
# Opens                                              -0.037611 -0.036563
# Remaining Budget                                         NaN       NaN
# Revenue                                             0.353915  0.425717
# Name_First Access Solid B                                NaN       NaN
# Data Provider (group)_Irvine                       -0.364106  0.030816
# Data Provider (group)_Venice                        0.364106 -0.030816
# Data Vertical_Auto Loan                            -0.114782  0.123512
# Data Vertical_Credit                                0.475423 -0.123018
# Data Vertical_FHA                                  -0.209726  0.066387
# Data Vertical_Grants                               -0.116409 -0.148796
# Data Vertical_Internal                             -0.228839 -0.037886
# Data Vertical_Paleo                                -0.139749 -0.005742
# Data Vertical_Personal Loan                        -0.066897  0.220633
# Data Vertical_Refinance                            -0.121699 -0.075817
# Data Vertical_Rent To Own                          -0.132271 -0.121590
# Offer Name1_First Access Solid Black Visa Credi...       NaN       NaN
# Operational Status1_Live                                 NaN       NaN
# Payout Type1_1st PAGE SUBMIT                             NaN       NaN
# Segment1_A14                                       -0.016997 -0.087376
# Segment1_A21                                       -0.075791  0.100967
# Segment1_MI                                        -0.258765  0.008349
# Segment1_O1                                         0.428862 -0.046820
# Segment1_O14                                       -0.010161  0.100101
# Segment1_O21                                        0.046614  0.181383
# Segment1_O30                                        0.004436 -0.197898
#
#                                                          CLR  # Drops  \
# Affiliate ID1                                      -0.186480      NaN
# eCPM                                               -0.266749      NaN
# CTR                                                -0.342789      NaN
# EPC                                                -0.033224      NaN
# CLR                                                 1.000000      NaN
# # Drops                                                  NaN      NaN
# Click Rate                                          0.542808      NaN
# Clicks                                             -0.228562      NaN
# Delivered                                           0.156511      NaN
# Offer ID1                                                NaN      NaN
# Open Rate                                          -0.489561      NaN
# Opens                                              -0.113891      NaN
# Remaining Budget                                         NaN      NaN
# Revenue                                            -0.223261      NaN
# Name_First Access Solid B                                NaN      NaN
# Data Provider (group)_Irvine                        0.600318      NaN
# Data Provider (group)_Venice                       -0.600318      NaN
# Data Vertical_Auto Loan                            -0.000451      NaN
# Data Vertical_Credit                               -0.183062      NaN
# Data Vertical_FHA                                   0.321996      NaN
# Data Vertical_Grants                                0.008251      NaN
# Data Vertical_Internal                              0.492582      NaN
# Data Vertical_Paleo                                -0.011437      NaN
# Data Vertical_Personal Loan                        -0.137022      NaN
# Data Vertical_Refinance                            -0.009363      NaN
# Data Vertical_Rent To Own                          -0.096324      NaN
# Offer Name1_First Access Solid Black Visa Credi...       NaN      NaN
# Operational Status1_Live                                 NaN      NaN
# Payout Type1_1st PAGE SUBMIT                             NaN      NaN
# Segment1_A14                                        0.004719      NaN
# Segment1_A21                                       -0.021125      NaN
# Segment1_MI                                         0.857698      NaN
# Segment1_O1                                        -0.063077      NaN
# Segment1_O14                                       -0.129848      NaN
# Segment1_O21                                       -0.019398      NaN
# Segment1_O30                                       -0.307558      NaN
#
#                                                     Click Rate    Clicks  \
# Affiliate ID1                                         0.120856 -0.118482
# eCPM                                                  0.217015  0.300535
# CTR                                                   0.316271  0.314267
# EPC                                                  -0.023298  0.044971
# CLR                                                   0.542808 -0.228562
# # Drops                                                    NaN       NaN
# Click Rate                                            1.000000 -0.046727
# Clicks                                               -0.046727  1.000000
# Delivered                                            -0.125642  0.665509
# Offer ID1                                                  NaN       NaN
# Open Rate                                            -0.184111  0.440485
# Opens                                                -0.285701  0.786386
# Remaining Budget                                           NaN       NaN
# Revenue                                              -0.020342  0.830225
# Name_First Access Solid B                                  NaN       NaN
# Data Provider (group)_Irvine                          0.149566  0.178530
# Data Provider (group)_Venice                         -0.149566 -0.178530
# Data Vertical_Auto Loan                              -0.011990 -0.100077
# Data Vertical_Credit                                  0.306448  0.067693
# Data Vertical_FHA                                    -0.005306 -0.112976
# Data Vertical_Grants                                 -0.151307 -0.120822
# Data Vertical_Internal                                0.356113  0.059981
# Data Vertical_Paleo                                  -0.167673 -0.090136
# Data Vertical_Personal Loan                          -0.164876 -0.071838
# Data Vertical_Refinance                              -0.200968  0.478848
# Data Vertical_Rent To Own                            -0.257972 -0.031624
# Offer Name1_First Access Solid Black Visa Credi...         NaN       NaN
# Operational Status1_Live                                   NaN       NaN
# Payout Type1_1st PAGE SUBMIT                               NaN       NaN
# Segment1_A14                                         -0.039476  0.019403
# Segment1_A21                                         -0.089314  0.001057
# Segment1_MI                                           0.523207 -0.114920
# Segment1_O1                                           0.086705  0.010727
# Segment1_O14                                         -0.142308  0.124962
# Segment1_O21                                          0.041043  0.055311
# Segment1_O30                                         -0.191939 -0.061887
#
#                                                     Delivered  Offer ID1  ...  \
# Affiliate ID1                                       -0.178661        NaN  ...
# eCPM                                                -0.204482        NaN  ...
# CTR                                                 -0.255454        NaN  ...
# EPC                                                 -0.082345        NaN  ...
# CLR                                                  0.156511        NaN  ...
# # Drops                                                   NaN        NaN  ...
# Click Rate                                          -0.125642        NaN  ...
# Clicks                                               0.665509        NaN  ...
# Delivered                                            1.000000        NaN  ...
# Offer ID1                                                 NaN        NaN  ...
# Open Rate                                           -0.054940        NaN  ...
# Opens                                                0.915146        NaN  ...
# Remaining Budget                                          NaN        NaN  ...
# Revenue                                              0.371417        NaN  ...
# Name_First Access Solid B                                 NaN        NaN  ...
# Data Provider (group)_Irvine                         0.583790        NaN  ...
# Data Provider (group)_Venice                        -0.583790        NaN  ...
# Data Vertical_Auto Loan                             -0.042835        NaN  ...
# Data Vertical_Credit                                -0.188687        NaN  ...
# Data Vertical_FHA                                    0.005801        NaN  ...
# Data Vertical_Grants                                -0.054971        NaN  ...
# Data Vertical_Internal                               0.313774        NaN  ...
# Data Vertical_Paleo                                  0.109683        NaN  ...
# Data Vertical_Personal Loan                         -0.144050        NaN  ...
# Data Vertical_Refinance                              0.724215        NaN  ...
# Data Vertical_Rent To Own                           -0.003958        NaN  ...
# Offer Name1_First Access Solid Black Visa Credi...        NaN        NaN  ...
# Operational Status1_Live                                  NaN        NaN  ...
# Payout Type1_1st PAGE SUBMIT                              NaN        NaN  ...
# Segment1_A14                                         0.002225        NaN  ...
# Segment1_A21                                         0.013093        NaN  ...
# Segment1_MI                                          0.174818        NaN  ...
# Segment1_O1                                         -0.074866        NaN  ...
# Segment1_O14                                         0.012088        NaN  ...
# Segment1_O21                                        -0.032571        NaN  ...
# Segment1_O30                                        -0.051637        NaN  ...
#
#                                                     Offer Name1_First Access Solid Black Visa Credit Card - Display - Lead Submit - W4 (e-mail)  \
# Affiliate ID1                                                                                     NaN
# eCPM                                                                                              NaN
# CTR                                                                                               NaN
# EPC                                                                                               NaN
# CLR                                                                                               NaN
# # Drops                                                                                           NaN
# Click Rate                                                                                        NaN
# Clicks                                                                                            NaN
# Delivered                                                                                         NaN
# Offer ID1                                                                                         NaN
# Open Rate                                                                                         NaN
# Opens                                                                                             NaN
# Remaining Budget                                                                                  NaN
# Revenue                                                                                           NaN
# Name_First Access Solid B                                                                         NaN
# Data Provider (group)_Irvine                                                                      NaN
# Data Provider (group)_Venice                                                                      NaN
# Data Vertical_Auto Loan                                                                           NaN
# Data Vertical_Credit                                                                              NaN
# Data Vertical_FHA                                                                                 NaN
# Data Vertical_Grants                                                                              NaN
# Data Vertical_Internal                                                                            NaN
# Data Vertical_Paleo                                                                               NaN
# Data Vertical_Personal Loan                                                                       NaN
# Data Vertical_Refinance                                                                           NaN
# Data Vertical_Rent To Own                                                                         NaN
# Offer Name1_First Access Solid Black Visa Credi...                                                NaN
# Operational Status1_Live                                                                          NaN
# Payout Type1_1st PAGE SUBMIT                                                                      NaN
# Segment1_A14                                                                                      NaN
# Segment1_A21                                                                                      NaN
# Segment1_MI                                                                                       NaN
# Segment1_O1                                                                                       NaN
# Segment1_O14                                                                                      NaN
# Segment1_O21                                                                                      NaN
# Segment1_O30                                                                                      NaN
#
#                                                     Operational Status1_Live  \
# Affiliate ID1                                                            NaN
# eCPM                                                                     NaN
# CTR                                                                      NaN
# EPC                                                                      NaN
# CLR                                                                      NaN
# # Drops                                                                  NaN
# Click Rate                                                               NaN
# Clicks                                                                   NaN
# Delivered                                                                NaN
# Offer ID1                                                                NaN
# Open Rate                                                                NaN
# Opens                                                                    NaN
# Remaining Budget                                                         NaN
# Revenue                                                                  NaN
# Name_First Access Solid B                                                NaN
# Data Provider (group)_Irvine                                             NaN
# Data Provider (group)_Venice                                             NaN
# Data Vertical_Auto Loan                                                  NaN
# Data Vertical_Credit                                                     NaN
# Data Vertical_FHA                                                        NaN
# Data Vertical_Grants                                                     NaN
# Data Vertical_Internal                                                   NaN
# Data Vertical_Paleo                                                      NaN
# Data Vertical_Personal Loan                                              NaN
# Data Vertical_Refinance                                                  NaN
# Data Vertical_Rent To Own                                                NaN
# Offer Name1_First Access Solid Black Visa Credi...                       NaN
# Operational Status1_Live                                                 NaN
# Payout Type1_1st PAGE SUBMIT                                             NaN
# Segment1_A14                                                             NaN
# Segment1_A21                                                             NaN
# Segment1_MI                                                              NaN
# Segment1_O1                                                              NaN
# Segment1_O14                                                             NaN
# Segment1_O21                                                             NaN
# Segment1_O30                                                             NaN
#
#                                                     Payout Type1_1st PAGE SUBMIT  \
# Affiliate ID1                                                                NaN
# eCPM                                                                         NaN
# CTR                                                                          NaN
# EPC                                                                          NaN
# CLR                                                                          NaN
# # Drops                                                                      NaN
# Click Rate                                                                   NaN
# Clicks                                                                       NaN
# Delivered                                                                    NaN
# Offer ID1                                                                    NaN
# Open Rate                                                                    NaN
# Opens                                                                        NaN
# Remaining Budget                                                             NaN
# Revenue                                                                      NaN
# Name_First Access Solid B                                                    NaN
# Data Provider (group)_Irvine                                                 NaN
# Data Provider (group)_Venice                                                 NaN
# Data Vertical_Auto Loan                                                      NaN
# Data Vertical_Credit                                                         NaN
# Data Vertical_FHA                                                            NaN
# Data Vertical_Grants                                                         NaN
# Data Vertical_Internal                                                       NaN
# Data Vertical_Paleo                                                          NaN
# Data Vertical_Personal Loan                                                  NaN
# Data Vertical_Refinance                                                      NaN
# Data Vertical_Rent To Own                                                    NaN
# Offer Name1_First Access Solid Black Visa Credi...                           NaN
# Operational Status1_Live                                                     NaN
# Payout Type1_1st PAGE SUBMIT                                                 NaN
# Segment1_A14                                                                 NaN
# Segment1_A21                                                                 NaN
# Segment1_MI                                                                  NaN
# Segment1_O1                                                                  NaN
# Segment1_O14                                                                 NaN
# Segment1_O21                                                                 NaN
# Segment1_O30                                                                 NaN
#
#                                                     Segment1_A14  \
# Affiliate ID1                                          -0.225733
# eCPM                                                   -0.063048
# CTR                                                    -0.016997
# EPC                                                    -0.087376
# CLR                                                     0.004719
# # Drops                                                      NaN
# Click Rate                                             -0.039476
# Clicks                                                  0.019403
# Delivered                                               0.002225
# Offer ID1                                                    NaN
# Open Rate                                               0.007594
# Opens                                                   0.005849
# Remaining Budget                                             NaN
# Revenue                                                -0.038209
# Name_First Access Solid B                                    NaN
# Data Provider (group)_Irvine                           -0.033845
# Data Provider (group)_Venice                            0.033845
# Data Vertical_Auto Loan                                -0.009259
# Data Vertical_Credit                                    0.128915
# Data Vertical_FHA                                      -0.025208
# Data Vertical_Grants                                   -0.016188
# Data Vertical_Internal                                 -0.021099
# Data Vertical_Paleo                                    -0.009259
# Data Vertical_Personal Loan                            -0.076186
# Data Vertical_Refinance                                -0.013156
# Data Vertical_Rent To Own                              -0.028868
# Offer Name1_First Access Solid Black Visa Credi...           NaN
# Operational Status1_Live                                     NaN
# Payout Type1_1st PAGE SUBMIT                                 NaN
# Segment1_A14                                            1.000000
# Segment1_A21                                           -0.016188
# Segment1_MI                                            -0.023224
# Segment1_O1                                            -0.013156
# Segment1_O14                                           -0.027081
# Segment1_O21                                           -0.038439
# Segment1_O30                                           -0.139917
#
#                                                     Segment1_A21  Segment1_MI  \
# Affiliate ID1                                           0.149096    -0.242883
# eCPM                                                   -0.022905    -0.176863
# CTR                                                    -0.075791    -0.258765
# EPC                                                     0.100967     0.008349
# CLR                                                    -0.021125     0.857698
# # Drops                                                      NaN          NaN
# Click Rate                                             -0.089314     0.523207
# Clicks                                                  0.001057    -0.114920
# Delivered                                               0.013093     0.174818
# Offer ID1                                                    NaN          NaN
# Open Rate                                              -0.051371    -0.368419
# Opens                                                  -0.001887    -0.083439
# Remaining Budget                                             NaN          NaN
# Revenue                                                 0.045047    -0.075778
# Name_First Access Solid B                                    NaN          NaN
# Data Provider (group)_Irvine                           -0.059171     0.557687
# Data Provider (group)_Venice                            0.059171    -0.557687
# Data Vertical_Auto Loan                                -0.016188    -0.023224
# Data Vertical_Credit                                   -0.125571    -0.180153
# Data Vertical_FHA                                      -0.044071     0.264953
# Data Vertical_Grants                                   -0.028302    -0.040604
# Data Vertical_Internal                                 -0.036887     0.523915
# Data Vertical_Paleo                                    -0.016188    -0.023224
# Data Vertical_Personal Loan                             0.212481    -0.108438
# Data Vertical_Refinance                                -0.023000    -0.032997
# Data Vertical_Rent To Own                              -0.050469    -0.072407
# Offer Name1_First Access Solid Black Visa Credi...           NaN          NaN
# Operational Status1_Live                                     NaN          NaN
# Payout Type1_1st PAGE SUBMIT                                 NaN          NaN
# Segment1_A14                                           -0.016188    -0.023224
# Segment1_A21                                            1.000000    -0.040604
# Segment1_MI                                            -0.040604     1.000000
# Segment1_O1                                            -0.023000    -0.032997
# Segment1_O14                                           -0.047347    -0.067927
# Segment1_O21                                           -0.067203    -0.096414
# Segment1_O30                                           -0.244619    -0.350945
#
#                                                     Segment1_O1  Segment1_O14  \
# Affiliate ID1                                          0.032956      0.035416
# eCPM                                                   0.222694      0.041800
# CTR                                                    0.428862     -0.010161
# EPC                                                   -0.046820      0.100101
# CLR                                                   -0.063077     -0.129848
# # Drops                                                     NaN           NaN
# Click Rate                                             0.086705     -0.142308
# Clicks                                                 0.010727      0.124962
# Delivered                                             -0.074866      0.012088
# Offer ID1                                                   NaN           NaN
# Open Rate                                              0.364356      0.119507
# Opens                                                 -0.026360      0.054861
# Remaining Budget                                            NaN           NaN
# Revenue                                               -0.020201      0.147866
# Name_First Access Solid B                                   NaN           NaN
# Data Provider (group)_Irvine                          -0.048087     -0.098989
# Data Provider (group)_Venice                           0.048087      0.098989
# Data Vertical_Auto Loan                               -0.013156     -0.027081
# Data Vertical_Credit                                   0.183164     -0.210072
# Data Vertical_FHA                                     -0.035816     -0.073728
# Data Vertical_Grants                                  -0.023000     -0.047347
# Data Vertical_Internal                                -0.029977     -0.061710
# Data Vertical_Paleo                                   -0.013156     -0.027081
# Data Vertical_Personal Loan                           -0.108246      0.355465
# Data Vertical_Refinance                               -0.018692     -0.038478
# Data Vertical_Rent To Own                             -0.041015     -0.084432
# Offer Name1_First Access Solid Black Visa Credi...          NaN           NaN
# Operational Status1_Live                                    NaN           NaN
# Payout Type1_1st PAGE SUBMIT                                NaN           NaN
# Segment1_A14                                          -0.013156     -0.027081
# Segment1_A21                                          -0.023000     -0.047347
# Segment1_MI                                           -0.032997     -0.067927
# Segment1_O1                                            1.000000     -0.038478
# Segment1_O14                                          -0.038478      1.000000
# Segment1_O21                                          -0.054614     -0.112426
# Segment1_O30                                          -0.198795     -0.409229
#
#                                                     Segment1_O21  Segment1_O30
# Affiliate ID1                                           0.344865     -0.171214
# eCPM                                                    0.169260     -0.104952
# CTR                                                     0.046614      0.004436
# EPC                                                     0.181383     -0.197898
# CLR                                                    -0.019398     -0.307558
# # Drops                                                      NaN           NaN
# Click Rate                                              0.041043     -0.191939
# Clicks                                                  0.055311     -0.061887
# Delivered                                              -0.032571     -0.051637
# Offer ID1                                                    NaN           NaN
# Open Rate                                              -0.027505      0.045226
# Opens                                                  -0.019204      0.031329
# Remaining Budget                                             NaN           NaN
# Revenue                                                 0.152113     -0.159983
# Name_First Access Solid B                                    NaN           NaN
# Data Provider (group)_Irvine                           -0.055421     -0.134769
# Data Provider (group)_Venice                            0.055421      0.134769
# Data Vertical_Auto Loan                                -0.038439      0.066177
# Data Vertical_Credit                                   -0.242614      0.349369
# Data Vertical_FHA                                      -0.104648      0.019855
# Data Vertical_Grants                                   -0.067203      0.115698
# Data Vertical_Internal                                 -0.087589     -0.130976
# Data Vertical_Paleo                                    -0.038439      0.066177
# Data Vertical_Personal Loan                             0.395096     -0.464870
# Data Vertical_Refinance                                 0.143817     -0.052385
# Data Vertical_Rent To Own                              -0.119840      0.206319
# Offer Name1_First Access Solid Black Visa Credi...           NaN           NaN
# Operational Status1_Live                                     NaN           NaN
# Payout Type1_1st PAGE SUBMIT                                 NaN           NaN
# Segment1_A14                                           -0.038439     -0.139917
# Segment1_A21                                           -0.067203     -0.244619
# Segment1_MI                                            -0.096414     -0.350945
# Segment1_O1                                            -0.054614     -0.198795
# Segment1_O14                                           -0.112426     -0.409229
# Segment1_O21                                            1.000000     -0.580849
# Segment1_O30                                           -0.580849      1.000000
#
# [36 rows x 36 columns]

# %%
import pandas_profiling 
profile = pandas_profiling.ProfileReport(df)
profile.to_file("profile_report.html") #exporting to html file for a better view
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Summarize dataset', max=51.0, style=ProgressStyle(descrip…
# HBox(children=(FloatProgress(value=0.0, description='Generate report structure', max=1.0, style=ProgressStyle(…
# HBox(children=(FloatProgress(value=0.0, description='Render HTML', max=1.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='Export report to file', max=1.0, style=ProgressStyle(desc…
